# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
data = pd.read_csv(r"C:\Users\Keno\Downloads\dataset_phishing.csv")

# %%
data.shape
# Out:
# (11430, 89)

# %%
data.describe()
# Out:
#          length_url  length_hostname            ip       nb_dots  \
# count  11430.000000     11430.000000  11430.000000  11430.000000
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or  \
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# ...

# %%
pd.set_option('display.max_rows', 500)
data.isna().sum()
# no missing values
# Out:
# url                           0
# length_url                    0
# length_hostname               0
# ip                            0
# nb_dots                       0
# nb_hyphens                    0
# nb_at                         0
# nb_qm                         0
# nb_and                        0
# nb_or                         0
# nb_eq                         0
# nb_underscore                 0
# nb_tilde                      0
# nb_percent                    0
# nb_slash                      0
# nb_star                       0
# nb_colon                      0
# nb_comma                      0
# nb_semicolumn                 0
# nb_dollar                     0
# nb_space                      0
# nb_www                        0
# nb_com                        0
# nb_dslash                     0
# http_in_path                  0
# https_token                   0
# ratio_digits_url              0
# ratio_digits_host             0
# punycode                      0
# ...

# %%
data['status'] = data['status'].apply(lambda x: 1 if x == 'phishing' else 0)

# %%
data = data.drop(columns=['url'])

# %%
corr_matrix = data.corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.show()

# %%
correlation_threshold = 0.1

# %%
relevant_features = corr_matrix.index[abs(corr_matrix['status']) > correlation_threshold].tolist()
relevant_features.remove('status')

# %%
X = data[relevant_features]
y = data['status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.9305920093321668
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93      1732
#            1       0.93      0.93      0.93      1697
#
#     accuracy                           0.93      3429
#    macro avg       0.93      0.93      0.93      3429
# weighted avg       0.93      0.93      0.93      3429

# %%
pip install wandb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wandb login
# Out:
#   Cell In[6], line 1
#     wandb login
#           ^
# SyntaxError: invalid syntax

# %%
import wandb
import random

# start a new wandb run to track this script
wandb.init(
    # set the wandb project where this run will be logged
    project="my-awesome-project",

    # track hyperparameters and run metadata
    config={
    "learning_rate": 0.02,
    "architecture": "CNN",
    "dataset": "CIFAR-100",
    "epochs": 10,
    }
)

# simulate training
epochs = 10
offset = random.random() / 5
for epoch in range(2, epochs):
    acc = 1 - 2 ** -epoch - random.random() / epoch - offset
    loss = 2 ** -epoch + random.random() / epoch + offset

    # log metrics to wandb
    wandb.log({"acc": acc, "loss": loss})

# [optional] finish the wandb run, necessary in notebooks
wandb.finish()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: C:\Users\Keno\_netrc
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>C:\Users\Keno\wandb\run-20240722_201324-v8bqtelx</code>
# Syncing run <strong><a href='https://wandb.ai/kenwonder358-usiu/my-awesome-project/runs/v8bqtelx' target="_blank">efficient-night-1</a></strong> to <a href='https://wandb.ai/kenwonder358-usiu/my-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kenwonder358-usiu/my-awesome-project' target="_blank">https://wandb.ai/kenwonder358-usiu/my-awesome-project</a>
# ...
